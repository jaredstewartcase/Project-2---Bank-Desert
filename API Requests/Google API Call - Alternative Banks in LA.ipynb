# %%
import pandas as pd
import numpy as np
import requests
import json
from pprint import pprint
import time
from config import gkey

# %%
neighborhood_df = pd.read_csv("../Scraping/LA_Locations.csv", encoding="ISO-8859-1")

# %%
neighborhood_df['Neighborhood Lat'] = ""
neighborhood_df['Neighborhood Long'] = ""

neighborhood_df.head()
# Out:
#      LA Neighborhood  Median Rank  Median Income  Diversity Rank  \
# 0            Bel-Air            1          0.755             228
# 1       Hidden Hills            2          0.748             251
# 2      Rolling Hills            3          0.748             193
# 3      Beverly Crest            4          0.748             245
# 4  Pacific Palisades            5          0.743             250
#
#    Diversity Index Neighborhood Lat Neighborhood Long
# 0            0.301
# 1            0.207
# 2            0.396
# 3            0.230
# 4            0.210

# %%
altbank_data={"Neighborhood":[],
           "Alt Bank Name":[],
           "Alt Bank Lat":[],
           "Alt Bank Long": []
          }

# %%
location_url = "https://maps.googleapis.com/maps/api/geocode/json?"

params = {
    "key": gkey,
}

# %%
# use iterrows to iterate through pandas dataframe
for index, row in neighborhood_df.iterrows():

    # get restaurant type from df
    la_location = row['LA Neighborhood']

    # add keyword to params dict
    params['address'] = f"{la_location}+LA+CA"

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {la_location}.")
    response = requests.get(location_url, params=params).json()
     
    try:
        print(f"Locating the lat,long coordinates for {la_location}")
        
        neighborhood_df.loc[index, "Neighborhood Lat"] = (response["results"][0]["geometry"]["location"]["lat"])
        neighborhood_df.loc[index, "Neighborhood Long"] = (response["results"][0]["geometry"]["location"]["lng"])
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Retrieving Results for Index 0: Bel-Air.
# Locating the lat,long coordinates for Bel-Air
# ------------
# Retrieving Results for Index 1: Hidden Hills.
# Locating the lat,long coordinates for Hidden Hills
# ------------
# Retrieving Results for Index 2: Rolling Hills.
# Locating the lat,long coordinates for Rolling Hills
# ------------
# Retrieving Results for Index 3: Beverly Crest.
# Locating the lat,long coordinates for Beverly Crest
# ------------
# Retrieving Results for Index 4: Pacific Palisades.
# Locating the lat,long coordinates for Pacific Palisades
# ------------
# Retrieving Results for Index 5: Palos Verdes Estates.
# Locating the lat,long coordinates for Palos Verdes Estates
# ------------
# Retrieving Results for Index 6: San Marino.
# Locating the lat,long coordinates for San Marino
# ------------
# Retrieving Results for Index 7: La Ca̱ada Flintridge.
# Locating the lat,long coordinates for La Ca̱ada Flintridge
# ------------
# Retrieving Results for Index 8: Rolling Hills Estates.
# Locating the lat,long coordinates for Rolling Hills Estates
# ------------
# Retrieving Results for Index 9: Malibu.
# Locating the lat,long coordinates for Malibu
# ------------
# Retrieving Results for Index 10: La Habra Heights.
# Locating the lat,long coordinates for La Habra Heights
# ------------
# Retrieving Results for Index 11: Manhattan Beach.
# Locating the lat,long coordinates for Manhattan Beach
# ------------
# Retrieving Results for Index 12: Unincorporated Santa Monica Mountains.
# Locating the lat,long coordinates for Unincorporated Santa Monica Mountains
# ------------
# Retrieving Results for Index 13: Rancho Palos Verdes.
# Locating the lat,long coordinates for Rancho Palos Verdes
# ------------
# Retrieving Results for Index 14: Westlake Village.
# Locating the lat,long coordinates for Westlake Village
# ------------
# Retrieving Results for Index 15: Calabasas.
# Locating the lat,long coordinates for Calabasas
# ------------
# Retrieving Results for Index 16: West San Dimas.
# Locating the lat,long coordinates for West San Dimas
# ------------
# Retrieving Results for Index 17: Bradbury.
# Locating the lat,long coordinates for Bradbury
# ------------
# Retrieving Results for Index 18: Stevenson Ranch.
# Locating the lat,long coordinates for Stevenson Ranch
# ------------
# Retrieving Results for Index 19: Porter Ranch.
# Locating the lat,long coordinates for Porter Ranch
# ------------
# Retrieving Results for Index 20: Topanga.
# Locating the lat,long coordinates for Topanga
# ------------
# Retrieving Results for Index 21: Ladera Heights.
# Locating the lat,long coordinates for Ladera Heights
# ------------
# Retrieving Results for Index 22: Agoura Hills.
# Locating the lat,long coordinates for Agoura Hills
# ------------
# Retrieving Results for Index 23: Leona Valley.
# Locating the lat,long coordinates for Leona Valley
# ------------
# Retrieving Results for Index 24: Brentwood.
# Locating the lat,long coordinates for Brentwood
# ------------
# Retrieving Results for Index 25: Cheviot Hills.
# Locating the lat,long coordinates for Cheviot Hills
# ------------
# Retrieving Results for Index 26: Hermosa Beach.
# Locating the lat,long coordinates for Hermosa Beach
# ------------
# Retrieving Results for Index 27: Castaic.
# Locating the lat,long coordinates for Castaic
# ------------
# Retrieving Results for Index 28: Hollywood Hills West.
# Locating the lat,long coordinates for Hollywood Hills West
# ------------
# Retrieving Results for Index 29: Walnut.
# Locating the lat,long coordinates for Walnut
# ------------
# Retrieving Results for Index 30: Hasley Canyon.
# Locating the lat,long coordinates for Hasley Canyon
# ------------
# Retrieving Results for Index 31: Agua Dulce.
# Locating the lat,long coordinates for Agua Dulce
# ------------
# Retrieving Results for Index 32: Beverlywood.
# Locating the lat,long coordinates for Beverlywood
# ------------
# Retrieving Results for Index 33: Northwest Palmdale.
# Locating the lat,long coordinates for Northwest Palmdale
# ------------
# Retrieving Results for Index 34: West Hills.
# Locating the lat,long coordinates for West Hills
# ------------
# Retrieving Results for Index 35: Cerritos.
# Locating the lat,long coordinates for Cerritos
# ------------
# Retrieving Results for Index 36: Beverly Hills.
# Locating the lat,long coordinates for Beverly Hills
# ------------
# Retrieving Results for Index 37: Century City.
# Locating the lat,long coordinates for Century City
# ------------
# Retrieving Results for Index 38: North Whittier.
# Locating the lat,long coordinates for North Whittier
# ------------
# Retrieving Results for Index 39: Unincorporated Santa Susana Mountains.
# Locating the lat,long coordinates for Unincorporated Santa Susana Mountains
# ------------
# Retrieving Results for Index 40: Castaic Canyons.
# Locating the lat,long coordinates for Castaic Canyons
# ------------
# Retrieving Results for Index 41: San Pasqual.
# Locating the lat,long coordinates for San Pasqual
# ------------
# Retrieving Results for Index 42: Ridge Route.
# Locating the lat,long coordinates for Ridge Route
# ------------
# Retrieving Results for Index 43: Marina del Rey.
# Locating the lat,long coordinates for Marina del Rey
# ------------
# Retrieving Results for Index 44: Diamond Bar.
# Locating the lat,long coordinates for Diamond Bar
# ------------
# Retrieving Results for Index 45: Redondo Beach.
# Locating the lat,long coordinates for Redondo Beach
# ------------
# Retrieving Results for Index 46: Playa del Rey.
# Locating the lat,long coordinates for Playa del Rey
# ------------
# Retrieving Results for Index 47: Woodland Hills.
# Locating the lat,long coordinates for Woodland Hills
# ------------
# Retrieving Results for Index 48: Claremont.
# Locating the lat,long coordinates for Claremont
# ------------
# Retrieving Results for Index 49: Santa Clarita.
# Locating the lat,long coordinates for Santa Clarita
# ------------
# Retrieving Results for Index 50: Sierra Madre.
# Locating the lat,long coordinates for Sierra Madre
# ------------
# Retrieving Results for Index 51: West Los Angeles.
# Locating the lat,long coordinates for West Los Angeles
# ------------
# Retrieving Results for Index 52: Ramona.
# Locating the lat,long coordinates for Ramona
# ------------
# Retrieving Results for Index 53: Tujunga Canyons.
# Locating the lat,long coordinates for Tujunga Canyons
# ------------
# Retrieving Results for Index 54: Hancock Park.
# Locating the lat,long coordinates for Hancock Park
# ------------
# Retrieving Results for Index 55: San Dimas.
# Locating the lat,long coordinates for San Dimas
# ------------
# Retrieving Results for Index 56: Chatsworth.
# Locating the lat,long coordinates for Chatsworth
# ------------
# Retrieving Results for Index 57: Acton.
# Locating the lat,long coordinates for Acton
# ------------
# Retrieving Results for Index 58: El Segundo.
# Locating the lat,long coordinates for El Segundo
# ------------
# Retrieving Results for Index 59: Granada Hills.
# Locating the lat,long coordinates for Granada Hills
# ------------
# Retrieving Results for Index 60: La Mirada.
# Locating the lat,long coordinates for La Mirada
# ------------
# Retrieving Results for Index 61: La Verne.
# Locating the lat,long coordinates for La Verne
# ------------
# Retrieving Results for Index 62: Shadow Hills.
# Locating the lat,long coordinates for Shadow Hills
# ------------
# Retrieving Results for Index 63: La Crescenta-Montrose.
# Locating the lat,long coordinates for La Crescenta-Montrose
# ------------
# Retrieving Results for Index 64: Altadena.
# Locating the lat,long coordinates for Altadena
# ------------
# Retrieving Results for Index 65: Glendora.
# Locating the lat,long coordinates for Glendora
# ------------
# Retrieving Results for Index 66: Vernon.
# Locating the lat,long coordinates for Vernon
# ------------
# Retrieving Results for Index 67: View Park-Windsor Hills.
# Locating the lat,long coordinates for View Park-Windsor Hills
# ------------
# Retrieving Results for Index 68: Desert View Highlands.
# Locating the lat,long coordinates for Desert View Highlands
# ------------
# Retrieving Results for Index 69: Hacienda Heights.
# Locating the lat,long coordinates for Hacienda Heights
# ------------
# Retrieving Results for Index 70: Lakewood.
# Locating the lat,long coordinates for Lakewood
# ------------
# Retrieving Results for Index 71: Green Valley.
# Locating the lat,long coordinates for Green Valley
# ------------
# Retrieving Results for Index 72: Encino.
# Locating the lat,long coordinates for Encino
# ------------
# Retrieving Results for Index 73: Quartz Hill.
# Locating the lat,long coordinates for Quartz Hill
# ------------
# Retrieving Results for Index 74: Westchester.
# Locating the lat,long coordinates for Westchester
# ------------
# Retrieving Results for Index 75: Torrance.
# Locating the lat,long coordinates for Torrance
# ------------
# Retrieving Results for Index 76: South Pasadena.
# Locating the lat,long coordinates for South Pasadena
# ------------
# Retrieving Results for Index 77: Elizabeth Lake.
# Locating the lat,long coordinates for Elizabeth Lake
# ------------
# Retrieving Results for Index 78: Arcadia.
# Locating the lat,long coordinates for Arcadia
# ------------
# Retrieving Results for Index 79: Mission Hills.
# Locating the lat,long coordinates for Mission Hills
# ------------
# Retrieving Results for Index 80: Studio City.
# Locating the lat,long coordinates for Studio City
# ------------
# Retrieving Results for Index 81: Lake Hughes.
# Locating the lat,long coordinates for Lake Hughes
# ------------
# Retrieving Results for Index 82: East Pasadena.
# Locating the lat,long coordinates for East Pasadena
# ------------
# Retrieving Results for Index 83: Tarzana.
# Locating the lat,long coordinates for Tarzana
# ------------
# Retrieving Results for Index 84: Toluca Lake.
# Locating the lat,long coordinates for Toluca Lake
# ------------
# Retrieving Results for Index 85: Angeles Crest.
# Locating the lat,long coordinates for Angeles Crest
# ------------
# Retrieving Results for Index 86: Rowland Heights.
# Locating the lat,long coordinates for Rowland Heights
# ------------
# Retrieving Results for Index 87: Rancho Dominguez.
# Locating the lat,long coordinates for Rancho Dominguez
# ------------
# Retrieving Results for Index 88: West Covina.
# Locating the lat,long coordinates for West Covina
# ------------
# Retrieving Results for Index 89: Carthay.
# Locating the lat,long coordinates for Carthay
# ------------
# Retrieving Results for Index 90: Culver City.
# Locating the lat,long coordinates for Culver City
# ------------
# Retrieving Results for Index 91: Carson.
# Locating the lat,long coordinates for Carson
# ------------
# Retrieving Results for Index 92: Southeast Antelope Valley.
# Locating the lat,long coordinates for Southeast Antelope Valley
# ------------
# Retrieving Results for Index 93: Valinda.
# Locating the lat,long coordinates for Valinda
# ------------
# Retrieving Results for Index 94: East La Mirada.
# Locating the lat,long coordinates for East La Mirada
# ------------
# Retrieving Results for Index 95: Rancho Park.
# Locating the lat,long coordinates for Rancho Park
# ------------
# Retrieving Results for Index 96: Sherman Oaks.
# Locating the lat,long coordinates for Sherman Oaks
# ------------
# Retrieving Results for Index 97: Hollywood Hills.
# Locating the lat,long coordinates for Hollywood Hills
# ------------
# Retrieving Results for Index 98: Santa Monica.
# Locating the lat,long coordinates for Santa Monica
# ------------
# Retrieving Results for Index 99: Sunland.
# Locating the lat,long coordinates for Sunland
# ------------
# Retrieving Results for Index 100: Westwood.
# Locating the lat,long coordinates for Westwood
# ------------
# Retrieving Results for Index 101: Playa Vista.
# Locating the lat,long coordinates for Playa Vista
# ------------
# Retrieving Results for Index 102: Duarte.
# Locating the lat,long coordinates for Duarte
# ------------
# Retrieving Results for Index 103: Charter Oak.
# Locating the lat,long coordinates for Charter Oak
# ------------
# Retrieving Results for Index 104: Val Verde.
# Locating the lat,long coordinates for Val Verde
# ------------
# Retrieving Results for Index 105: Lake View Terrace.
# Locating the lat,long coordinates for Lake View Terrace
# ------------
# Retrieving Results for Index 106: Northridge.
# Locating the lat,long coordinates for Northridge
# ------------
# Retrieving Results for Index 107: Venice.
# Locating the lat,long coordinates for Venice
# ------------
# Retrieving Results for Index 108: Mayflower Village.
# Locating the lat,long coordinates for Mayflower Village
# ------------
# Retrieving Results for Index 109: Eagle Rock.
# Locating the lat,long coordinates for Eagle Rock
# ------------
# Retrieving Results for Index 110: Whittier.
# Locating the lat,long coordinates for Whittier
# ------------
# Retrieving Results for Index 111: West Carson.
# Locating the lat,long coordinates for West Carson
# ------------
# Retrieving Results for Index 112: Citrus.
# Locating the lat,long coordinates for Citrus
# ------------
# Retrieving Results for Index 113: Industry.
# Locating the lat,long coordinates for Industry
# ------------
# Retrieving Results for Index 114: Del Aire.
# Locating the lat,long coordinates for Del Aire
# ------------
# Retrieving Results for Index 115: Covina.
# Locating the lat,long coordinates for Covina
# ------------
# Retrieving Results for Index 116: Signal Hill.
# Locating the lat,long coordinates for Signal Hill
# ------------
# Retrieving Results for Index 117: Vincent.
# Locating the lat,long coordinates for Vincent
# ------------
# Retrieving Results for Index 118: Temple City.
# Locating the lat,long coordinates for Temple City
# ------------
# Retrieving Results for Index 119: Fairfax.
# Locating the lat,long coordinates for Fairfax
# ------------
# Retrieving Results for Index 120: Sylmar.
# Locating the lat,long coordinates for Sylmar
# ------------
# Retrieving Results for Index 121: Arleta.
# Locating the lat,long coordinates for Arleta
# ------------
# Retrieving Results for Index 122: South San Jose Hills.
# Locating the lat,long coordinates for South San Jose Hills
# ------------
# Retrieving Results for Index 123: Lake Balboa.
# Locating the lat,long coordinates for Lake Balboa
# ------------
# Retrieving Results for Index 124: South San Gabriel.
# Locating the lat,long coordinates for South San Gabriel
# ------------
# Retrieving Results for Index 125: West Puente Valley.
# Locating the lat,long coordinates for West Puente Valley
# ------------
# Retrieving Results for Index 126: South Whittier.
# Locating the lat,long coordinates for South Whittier
# ------------
# Retrieving Results for Index 127: Avocado Heights.
# Locating the lat,long coordinates for Avocado Heights
# ------------
# Retrieving Results for Index 128: Burbank.
# Locating the lat,long coordinates for Burbank
# ------------
# Retrieving Results for Index 129: East San Gabriel.
# Locating the lat,long coordinates for East San Gabriel
# ------------
# Retrieving Results for Index 130: Pico-Robertson.
# Locating the lat,long coordinates for Pico-Robertson
# ------------
# Retrieving Results for Index 131: Palmdale.
# Locating the lat,long coordinates for Palmdale
# ------------
# Retrieving Results for Index 132: Beverly Grove.
# Locating the lat,long coordinates for Beverly Grove
# ------------
# Retrieving Results for Index 133: Pasadena.
# Locating the lat,long coordinates for Pasadena
# ------------
# Retrieving Results for Index 134: Mar Vista.
# Locating the lat,long coordinates for Mar Vista
# ------------
# Retrieving Results for Index 135: Winnetka.
# Locating the lat,long coordinates for Winnetka
# ------------
# Retrieving Results for Index 136: Norwalk.
# Locating the lat,long coordinates for Norwalk
# ------------
# Retrieving Results for Index 137: Del Rey.
# Locating the lat,long coordinates for Del Rey
# ------------
# Retrieving Results for Index 138: Downey.
# Locating the lat,long coordinates for Downey
# ------------
# Retrieving Results for Index 139: Windsor Square.
# Locating the lat,long coordinates for Windsor Square
# ------------
# Retrieving Results for Index 140: West Whittier-Los Nietos.
# Locating the lat,long coordinates for West Whittier-Los Nietos
# ------------
# Retrieving Results for Index 141: Monrovia.
# Locating the lat,long coordinates for Monrovia
# ------------
# Retrieving Results for Index 142: Lopez/Kagel Canyons.
# Locating the lat,long coordinates for Lopez/Kagel Canyons
# ------------
# Retrieving Results for Index 143: Irwindale.
# Locating the lat,long coordinates for Irwindale
# ------------
# Retrieving Results for Index 144: Littlerock.
# Locating the lat,long coordinates for Littlerock
# ------------
# Retrieving Results for Index 145: Veterans Administration.
# Locating the lat,long coordinates for Veterans Administration
# ------------
# Retrieving Results for Index 146: Artesia.
# Locating the lat,long coordinates for Artesia
# ------------
# Retrieving Results for Index 147: Santa Fe Springs.
# Locating the lat,long coordinates for Santa Fe Springs
# ------------
# Retrieving Results for Index 148: Lomita.
# Locating the lat,long coordinates for Lomita
# ------------
# Retrieving Results for Index 149: Northwest Antelope Valley.
# Locating the lat,long coordinates for Northwest Antelope Valley
# ------------
# Retrieving Results for Index 150: Mid-Wilshire.
# Locating the lat,long coordinates for Mid-Wilshire
# ------------
# Retrieving Results for Index 151: Tujunga.
# Locating the lat,long coordinates for Tujunga
# ------------
# Retrieving Results for Index 152: Gramercy Park.
# Locating the lat,long coordinates for Gramercy Park
# ------------
# Retrieving Results for Index 153: Mount Washington.
# Locating the lat,long coordinates for Mount Washington
# ------------
# Retrieving Results for Index 154: Sawtelle.
# Locating the lat,long coordinates for Sawtelle
# ------------
# Retrieving Results for Index 155: San Pedro.
# Locating the lat,long coordinates for San Pedro
# ------------
# Retrieving Results for Index 156: Alondra Park.
# Locating the lat,long coordinates for Alondra Park
# ------------
# Retrieving Results for Index 157: Glendale.
# Locating the lat,long coordinates for Glendale
# ------------
# Retrieving Results for Index 158: San Gabriel.
# Locating the lat,long coordinates for San Gabriel
# ------------
# Retrieving Results for Index 159: Pico Rivera.
# Locating the lat,long coordinates for Pico Rivera
# ------------
# Retrieving Results for Index 160: Baldwin Park.
# Locating the lat,long coordinates for Baldwin Park
# ------------
# Retrieving Results for Index 161: North El Monte.
# Locating the lat,long coordinates for North El Monte
# ------------
# Retrieving Results for Index 162: Unincorporated Catalina Island.
# Locating the lat,long coordinates for Unincorporated Catalina Island
# ------------
# Retrieving Results for Index 163: Sun Village.
# Locating the lat,long coordinates for Sun Village
# ------------
# Retrieving Results for Index 164: Lancaster.
# Locating the lat,long coordinates for Lancaster
# ------------
# Retrieving Results for Index 165: La Puente.
# Locating the lat,long coordinates for La Puente
# ------------
# Retrieving Results for Index 166: Montecito Heights.
# Locating the lat,long coordinates for Montecito Heights
# ------------
# Retrieving Results for Index 167: Valley Village.
# Locating the lat,long coordinates for Valley Village
# ------------
# Retrieving Results for Index 168: Harbor City.
# Locating the lat,long coordinates for Harbor City
# ------------
# Retrieving Results for Index 169: Monterey Park.
# Locating the lat,long coordinates for Monterey Park
# ------------
# Retrieving Results for Index 170: Reseda.
# Locating the lat,long coordinates for Reseda
# ------------
# Retrieving Results for Index 171: Silver Lake.
# Locating the lat,long coordinates for Silver Lake
# ------------
# Retrieving Results for Index 172: Pomona.
# Locating the lat,long coordinates for Pomona
# ------------
# Retrieving Results for Index 173: San Fernando.
# Locating the lat,long coordinates for San Fernando
# ------------
# Retrieving Results for Index 174: Atwater Village.
# Locating the lat,long coordinates for Atwater Village
# ------------
# Retrieving Results for Index 175: Bellflower.
# Locating the lat,long coordinates for Bellflower
# ------------
# Retrieving Results for Index 176: Azusa.
# Locating the lat,long coordinates for Azusa
# ------------
# Retrieving Results for Index 177: Alhambra.
# Locating the lat,long coordinates for Alhambra
# ------------
# Retrieving Results for Index 178: Avalon.
# Locating the lat,long coordinates for Avalon
# ------------
# Retrieving Results for Index 179: Lawndale.
# Locating the lat,long coordinates for Lawndale
# ------------
# Retrieving Results for Index 180: Gardena.
# Locating the lat,long coordinates for Gardena
# ------------
# Retrieving Results for Index 181: West Hollywood.
# Locating the lat,long coordinates for West Hollywood
# ------------
# Retrieving Results for Index 182: Montebello.
# Locating the lat,long coordinates for Montebello
# ------------
# Retrieving Results for Index 183: North Hills.
# Locating the lat,long coordinates for North Hills
# ------------
# Retrieving Results for Index 184: Northeast Antelope Valley.
# Locating the lat,long coordinates for Northeast Antelope Valley
# ------------
# Retrieving Results for Index 185: Lake Los Angeles.
# Locating the lat,long coordinates for Lake Los Angeles
# ------------
# Retrieving Results for Index 186: Canoga Park.
# Locating the lat,long coordinates for Canoga Park
# ------------
# Retrieving Results for Index 187: Sun Valley.
# Locating the lat,long coordinates for Sun Valley
# ------------
# Retrieving Results for Index 188: Long Beach.
# Locating the lat,long coordinates for Long Beach
# ------------
# Retrieving Results for Index 189: Los Feliz.
# Locating the lat,long coordinates for Los Feliz
# ------------
# Retrieving Results for Index 190: Palms.
# Locating the lat,long coordinates for Palms
# ------------
# Retrieving Results for Index 191: Glassell Park.
# Locating the lat,long coordinates for Glassell Park
# ------------
# Retrieving Results for Index 192: Paramount.
# Locating the lat,long coordinates for Paramount
# ------------
# Retrieving Results for Index 193: Rosemead.
# Locating the lat,long coordinates for Rosemead
# ------------
# Retrieving Results for Index 194: Pacoima.
# Locating the lat,long coordinates for Pacoima
# ------------
# Retrieving Results for Index 195: Elysian Valley.
# Locating the lat,long coordinates for Elysian Valley
# ------------
# Retrieving Results for Index 196: Athens.
# Locating the lat,long coordinates for Athens
# ------------
# Retrieving Results for Index 197: Walnut Park.
# Locating the lat,long coordinates for Walnut Park
# ------------
# Retrieving Results for Index 198: Lynwood.
# Locating the lat,long coordinates for Lynwood
# ------------
# Retrieving Results for Index 199: South Gate.
# Locating the lat,long coordinates for South Gate
# ------------
# Retrieving Results for Index 200: West Compton.
# Locating the lat,long coordinates for West Compton
# ------------
# Retrieving Results for Index 201: Harbor Gateway.
# Locating the lat,long coordinates for Harbor Gateway
# ------------
# Retrieving Results for Index 202: Larchmont.
# Locating the lat,long coordinates for Larchmont
# ------------
# Retrieving Results for Index 203: South El Monte.
# Locating the lat,long coordinates for South El Monte
# ------------
# Retrieving Results for Index 204: Hawaiian Gardens.
# Locating the lat,long coordinates for Hawaiian Gardens
# ------------
# Retrieving Results for Index 205: Inglewood.
# Locating the lat,long coordinates for Inglewood
# ------------
# Retrieving Results for Index 206: Commerce.
# Locating the lat,long coordinates for Commerce
# ------------
# Retrieving Results for Index 207: Valley Glen.
# Locating the lat,long coordinates for Valley Glen
# ------------
# Retrieving Results for Index 208: Manchester Square.
# Locating the lat,long coordinates for Manchester Square
# ------------
# Retrieving Results for Index 209: El Sereno.
# Locating the lat,long coordinates for El Sereno
# ------------
# Retrieving Results for Index 210: Leimert Park.
# Locating the lat,long coordinates for Leimert Park
# ------------
# Retrieving Results for Index 211: Highland Park.
# Locating the lat,long coordinates for Highland Park
# ------------
# Retrieving Results for Index 212: Panorama City.
# Locating the lat,long coordinates for Panorama City
# ------------
# Retrieving Results for Index 213: East Compton.
# Locating the lat,long coordinates for East Compton
# ------------
# Retrieving Results for Index 214: El Monte.
# Locating the lat,long coordinates for El Monte
# ------------
# Retrieving Results for Index 215: Mid-City.
# Locating the lat,long coordinates for Mid-City
# ------------
# Retrieving Results for Index 216: Hawthorne.
# Locating the lat,long coordinates for Hawthorne
# ------------
# Retrieving Results for Index 217: Compton.
# Locating the lat,long coordinates for Compton
# ------------
# Retrieving Results for Index 218: North Hollywood.
# Locating the lat,long coordinates for North Hollywood
# ------------
# Retrieving Results for Index 219: Cypress Park.
# Locating the lat,long coordinates for Cypress Park
# ------------
# Retrieving Results for Index 220: Bell Gardens.
# Locating the lat,long coordinates for Bell Gardens
# ------------
# Retrieving Results for Index 221: Maywood.
# Locating the lat,long coordinates for Maywood
# ------------
# Retrieving Results for Index 222: Van Nuys.
# Locating the lat,long coordinates for Van Nuys
# ------------
# Retrieving Results for Index 223: Wilmington.
# Locating the lat,long coordinates for Wilmington
# ------------
# Retrieving Results for Index 224: Bell.
# Locating the lat,long coordinates for Bell
# ------------
# Retrieving Results for Index 225: Hyde Park.
# Locating the lat,long coordinates for Hyde Park
# ------------
# Retrieving Results for Index 226: Huntington Park.
# Locating the lat,long coordinates for Huntington Park
# ------------
# Retrieving Results for Index 227: Cudahy.
# Locating the lat,long coordinates for Cudahy
# ------------
# Retrieving Results for Index 228: East Los Angeles.
# Locating the lat,long coordinates for East Los Angeles
# ------------
# Retrieving Results for Index 229: Willowbrook.
# Locating the lat,long coordinates for Willowbrook
# ------------
# Retrieving Results for Index 230: West Adams.
# Locating the lat,long coordinates for West Adams
# ------------
# Retrieving Results for Index 231: Baldwin Hills/Crenshaw.
# Locating the lat,long coordinates for Baldwin Hills/Crenshaw
# ------------
# Retrieving Results for Index 232: Lennox.
# Locating the lat,long coordinates for Lennox
# ------------
# Retrieving Results for Index 233: Chesterfield Square.
# Locating the lat,long coordinates for Chesterfield Square
# ------------
# Retrieving Results for Index 234: Echo Park.
# Locating the lat,long coordinates for Echo Park
# ------------
# Retrieving Results for Index 235: Harvard Park.
# Locating the lat,long coordinates for Harvard Park
# ------------
# Retrieving Results for Index 236: Florence-Firestone.
# Locating the lat,long coordinates for Florence-Firestone
# ------------
# Retrieving Results for Index 237: Exposition Park.
# Locating the lat,long coordinates for Exposition Park
# ------------
# Retrieving Results for Index 238: Hollywood.
# Locating the lat,long coordinates for Hollywood
# ------------
# Retrieving Results for Index 239: Boyle Heights.
# Locating the lat,long coordinates for Boyle Heights
# ------------
# Retrieving Results for Index 240: Jefferson Park.
# Locating the lat,long coordinates for Jefferson Park
# ------------
# Retrieving Results for Index 241: Westmont.
# Locating the lat,long coordinates for Westmont
# ------------
# Retrieving Results for Index 242: Central-Alameda.
# Locating the lat,long coordinates for Central-Alameda
# ------------
# Retrieving Results for Index 243: Arlington Heights.
# Locating the lat,long coordinates for Arlington Heights
# ------------
# Retrieving Results for Index 244: Green Meadows.
# Locating the lat,long coordinates for Green Meadows
# ------------
# Retrieving Results for Index 245: Vermont Vista.
# Locating the lat,long coordinates for Vermont Vista
# ------------
# Retrieving Results for Index 246: Vermont-Slauson.
# Locating the lat,long coordinates for Vermont-Slauson
# ------------
# Retrieving Results for Index 247: Harvard Heights.
# Locating the lat,long coordinates for Harvard Heights
# ------------
# Retrieving Results for Index 248: Historic South-Central.
# Locating the lat,long coordinates for Historic South-Central
# ------------
# Retrieving Results for Index 249: Lincoln Heights.
# Locating the lat,long coordinates for Lincoln Heights
# ------------
# Retrieving Results for Index 250: Koreatown.
# Locating the lat,long coordinates for Koreatown
# ------------
# Retrieving Results for Index 251: East Hollywood.
# Locating the lat,long coordinates for East Hollywood
# ------------
# Retrieving Results for Index 252: Vermont Square.
# Locating the lat,long coordinates for Vermont Square
# ------------
# Retrieving Results for Index 253: Broadway-Manchester.
# Locating the lat,long coordinates for Broadway-Manchester
# ------------
# Retrieving Results for Index 254: Adams-Normandie.
# Locating the lat,long coordinates for Adams-Normandie
# ------------
# Retrieving Results for Index 255: South Park.
# Locating the lat,long coordinates for South Park
# ------------
# Retrieving Results for Index 256: Florence.
# Locating the lat,long coordinates for Florence
# ------------
# Retrieving Results for Index 257: Elysian Park.
# Locating the lat,long coordinates for Elysian Park
# ------------
# Retrieving Results for Index 258: Vermont Knolls.
# Locating the lat,long coordinates for Vermont Knolls
# ------------
# Retrieving Results for Index 259: Westlake.
# Locating the lat,long coordinates for Westlake
# ------------
# Retrieving Results for Index 260: Pico-Union.
# Locating the lat,long coordinates for Pico-Union
# ------------
# Retrieving Results for Index 261: Watts.
# Locating the lat,long coordinates for Watts
# ------------
# Retrieving Results for Index 262: Chinatown.
# Locating the lat,long coordinates for Chinatown
# ------------
# Retrieving Results for Index 263: University Park.
# Locating the lat,long coordinates for University Park
# ------------
# Retrieving Results for Index 264: Downtown.
# Locating the lat,long coordinates for Downtown
# ------------

# %%
bank = 1
radius = 5000
params = {
    "radius": radius,
    "key": gkey
}

# use iterrows to iterate through pandas dataframe
for index, row in neighborhood_df.iterrows():
    neighbor = row["LA Neighborhood"]
    lat = row["Neighborhood Lat"]
    long = row["Neighborhood Long"]
    la_coords = f"{lat},{long}"

    count = 0
    page = 1
    current = 1

    
    print(f"{bank}. Locating the Alternative Banks in {neighbor}, CA")
    bank = bank + 1
    
    for i in range (0,3):
        try:
            print(f"Page: {page}")
            if count < 1:
        
                params['location'] = la_coords
                url_pass1 = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?keyword=check%20cashing"
    
                response1 = requests.get(url_pass1, params)
                bank_data1 = response1.json()
            
                for x in range(len(bank_data1["results"])):
                    altbank_data["Neighborhood"].append(neighbor)
                    altbank_data["Alt Bank Name"].append(bank_data1["results"][x]["name"])
                    altbank_data["Alt Bank Lat"].append(bank_data1["results"][x]["geometry"]["location"]["lat"])
                    altbank_data["Alt Bank Long"].append(bank_data1["results"][x]["geometry"]["location"]["lng"])
    
                time.sleep(2)
    
                count = count + 1
                current = current + 1
                page = page + 1
               
                try:
                    pagetoken = bank_data1["next_page_token"]
                except (KeyError, IndexError):
                    print(f"There are no more alternative banks in {neighbor}, CA.")
                    break
    
            else:
            
                params['location'] = la_coords
    
                url_pass2 = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?keyword=check%20cashing&pagetoken={pagetoken}"
    
                response2 = requests.get(url_pass2, params)
                bank_data2 = response2.json()
            
                for x in range(len(bank_data1["results"])):
                    altbank_data["Neighborhood"].append(neighbor)
                    altbank_data["Alt Bank Name"].append(bank_data2["results"][x]["name"])
                    altbank_data["Alt Bank Lat"].append(bank_data2["results"][x]["geometry"]["location"]["lat"])
                    altbank_data["Alt Bank Long"].append(bank_data2["results"][x]["geometry"]["location"]["lng"])
    
                time.sleep(2)
    
                count = count + 1
                page = page + 1
                current = current + 1
                
                try:
                    pagetoken = bank_data2["next_page_token"]
                except (KeyError, IndexError):
                    print(f"There are no more alternative banks in {neighbor}, CA.")
                    break
        except (KeyError, IndexError):
            print(f"There are no more alternative banks in {neighbor}, CA.")
            break
        
    print("------------")
# Out:
# 1. Locating the Alternative Banks in Bel-Air, CA
# Page: 1
# There are no more alternative banks in Bel-Air, CA.
# ------------
# 2. Locating the Alternative Banks in Hidden Hills, CA
# Page: 1
# There are no more alternative banks in Hidden Hills, CA.
# ------------
# 3. Locating the Alternative Banks in Rolling Hills, CA
# Page: 1
# There are no more alternative banks in Rolling Hills, CA.
# ------------
# 4. Locating the Alternative Banks in Beverly Crest, CA
# Page: 1
# There are no more alternative banks in Beverly Crest, CA.
# ------------
# 5. Locating the Alternative Banks in Pacific Palisades, CA
# Page: 1
# There are no more alternative banks in Pacific Palisades, CA.
# ------------
# 6. Locating the Alternative Banks in Palos Verdes Estates, CA
# Page: 1
# There are no more alternative banks in Palos Verdes Estates, CA.
# ------------
# 7. Locating the Alternative Banks in San Marino, CA
# Page: 1
# There are no more alternative banks in San Marino, CA.
# ------------
# 8. Locating the Alternative Banks in La Ca̱ada Flintridge, CA
# Page: 1
# There are no more alternative banks in La Ca̱ada Flintridge, CA.
# ------------
# 9. Locating the Alternative Banks in Rolling Hills Estates, CA
# Page: 1
# There are no more alternative banks in Rolling Hills Estates, CA.
# ------------
# 10. Locating the Alternative Banks in Malibu, CA
# Page: 1
# There are no more alternative banks in Malibu, CA.
# ------------
# 11. Locating the Alternative Banks in La Habra Heights, CA
# Page: 1
# There are no more alternative banks in La Habra Heights, CA.
# ------------
# 12. Locating the Alternative Banks in Manhattan Beach, CA
# Page: 1
# There are no more alternative banks in Manhattan Beach, CA.
# ------------
# 13. Locating the Alternative Banks in Unincorporated Santa Monica Mountains, CA
# Page: 1
# There are no more alternative banks in Unincorporated Santa Monica Mountains, CA.
# ------------
# 14. Locating the Alternative Banks in Rancho Palos Verdes, CA
# Page: 1
# There are no more alternative banks in Rancho Palos Verdes, CA.
# ------------
# 15. Locating the Alternative Banks in Westlake Village, CA
# Page: 1
# There are no more alternative banks in Westlake Village, CA.
# ------------
# 16. Locating the Alternative Banks in Calabasas, CA
# Page: 1
# There are no more alternative banks in Calabasas, CA.
# ------------
# 17. Locating the Alternative Banks in West San Dimas, CA
# Page: 1
# There are no more alternative banks in West San Dimas, CA.
# ------------
# 18. Locating the Alternative Banks in Bradbury, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Bradbury, CA.
# ------------
# 19. Locating the Alternative Banks in Stevenson Ranch, CA
# Page: 1
# There are no more alternative banks in Stevenson Ranch, CA.
# ------------
# 20. Locating the Alternative Banks in Porter Ranch, CA
# Page: 1
# There are no more alternative banks in Porter Ranch, CA.
# ------------
# 21. Locating the Alternative Banks in Topanga, CA
# Page: 1
# There are no more alternative banks in Topanga, CA.
# ------------
# 22. Locating the Alternative Banks in Ladera Heights, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Ladera Heights, CA.
# ------------
# 23. Locating the Alternative Banks in Agoura Hills, CA
# Page: 1
# There are no more alternative banks in Agoura Hills, CA.
# ------------
# 24. Locating the Alternative Banks in Leona Valley, CA
# Page: 1
# There are no more alternative banks in Leona Valley, CA.
# ------------
# 25. Locating the Alternative Banks in Brentwood, CA
# Page: 1
# There are no more alternative banks in Brentwood, CA.
# ------------
# 26. Locating the Alternative Banks in Cheviot Hills, CA
# Page: 1
# There are no more alternative banks in Cheviot Hills, CA.
# ------------
# 27. Locating the Alternative Banks in Hermosa Beach, CA
# Page: 1
# There are no more alternative banks in Hermosa Beach, CA.
# ------------
# 28. Locating the Alternative Banks in Castaic, CA
# Page: 1
# There are no more alternative banks in Castaic, CA.
# ------------
# 29. Locating the Alternative Banks in Hollywood Hills West, CA
# Page: 1
# There are no more alternative banks in Hollywood Hills West, CA.
# ------------
# 30. Locating the Alternative Banks in Walnut, CA
# Page: 1
# There are no more alternative banks in Walnut, CA.
# ------------
# 31. Locating the Alternative Banks in Hasley Canyon, CA
# Page: 1
# There are no more alternative banks in Hasley Canyon, CA.
# ------------
# 32. Locating the Alternative Banks in Agua Dulce, CA
# Page: 1
# There are no more alternative banks in Agua Dulce, CA.
# ------------
# 33. Locating the Alternative Banks in Beverlywood, CA
# Page: 1
# There are no more alternative banks in Beverlywood, CA.
# ------------
# 34. Locating the Alternative Banks in Northwest Palmdale, CA
# Page: 1
# There are no more alternative banks in Northwest Palmdale, CA.
# ------------
# 35. Locating the Alternative Banks in West Hills, CA
# Page: 1
# There are no more alternative banks in West Hills, CA.
# ------------
# 36. Locating the Alternative Banks in Cerritos, CA
# Page: 1
# There are no more alternative banks in Cerritos, CA.
# ------------
# 37. Locating the Alternative Banks in Beverly Hills, CA
# Page: 1
# There are no more alternative banks in Beverly Hills, CA.
# ------------
# 38. Locating the Alternative Banks in Century City, CA
# Page: 1
# There are no more alternative banks in Century City, CA.
# ------------
# 39. Locating the Alternative Banks in North Whittier, CA
# Page: 1
# There are no more alternative banks in North Whittier, CA.
# ------------
# 40. Locating the Alternative Banks in Unincorporated Santa Susana Mountains, CA
# Page: 1
# There are no more alternative banks in Unincorporated Santa Susana Mountains, CA.
# ------------
# 41. Locating the Alternative Banks in Castaic Canyons, CA
# Page: 1
# There are no more alternative banks in Castaic Canyons, CA.
# ------------
# 42. Locating the Alternative Banks in San Pasqual, CA
# Page: 1
# There are no more alternative banks in San Pasqual, CA.
# ------------
# 43. Locating the Alternative Banks in Ridge Route, CA
# Page: 1
# There are no more alternative banks in Ridge Route, CA.
# ------------
# 44. Locating the Alternative Banks in Marina del Rey, CA
# Page: 1
# There are no more alternative banks in Marina del Rey, CA.
# ------------
# 45. Locating the Alternative Banks in Diamond Bar, CA
# Page: 1
# There are no more alternative banks in Diamond Bar, CA.
# ------------
# 46. Locating the Alternative Banks in Redondo Beach, CA
# Page: 1
# There are no more alternative banks in Redondo Beach, CA.
# ------------
# 47. Locating the Alternative Banks in Playa del Rey, CA
# Page: 1
# There are no more alternative banks in Playa del Rey, CA.
# ------------
# 48. Locating the Alternative Banks in Woodland Hills, CA
# Page: 1
# There are no more alternative banks in Woodland Hills, CA.
# ------------
# 49. Locating the Alternative Banks in Claremont, CA
# Page: 1
# There are no more alternative banks in Claremont, CA.
# ------------
# 50. Locating the Alternative Banks in Santa Clarita, CA
# Page: 1
# There are no more alternative banks in Santa Clarita, CA.
# ------------
# 51. Locating the Alternative Banks in Sierra Madre, CA
# Page: 1
# There are no more alternative banks in Sierra Madre, CA.
# ------------
# 52. Locating the Alternative Banks in West Los Angeles, CA
# Page: 1
# There are no more alternative banks in West Los Angeles, CA.
# ------------
# 53. Locating the Alternative Banks in Ramona, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Ramona, CA.
# ------------
# 54. Locating the Alternative Banks in Tujunga Canyons, CA
# Page: 1
# There are no more alternative banks in Tujunga Canyons, CA.
# ------------
# 55. Locating the Alternative Banks in Hancock Park, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Hancock Park, CA.
# ------------
# 56. Locating the Alternative Banks in San Dimas, CA
# Page: 1
# There are no more alternative banks in San Dimas, CA.
# ------------
# 57. Locating the Alternative Banks in Chatsworth, CA
# Page: 1
# There are no more alternative banks in Chatsworth, CA.
# ------------
# 58. Locating the Alternative Banks in Acton, CA
# Page: 1
# There are no more alternative banks in Acton, CA.
# ------------
# 59. Locating the Alternative Banks in El Segundo, CA
# Page: 1
# There are no more alternative banks in El Segundo, CA.
# ------------
# 60. Locating the Alternative Banks in Granada Hills, CA
# Page: 1
# There are no more alternative banks in Granada Hills, CA.
# ------------
# 61. Locating the Alternative Banks in La Mirada, CA
# Page: 1
# There are no more alternative banks in La Mirada, CA.
# ------------
# 62. Locating the Alternative Banks in La Verne, CA
# Page: 1
# There are no more alternative banks in La Verne, CA.
# ------------
# 63. Locating the Alternative Banks in Shadow Hills, CA
# Page: 1
# There are no more alternative banks in Shadow Hills, CA.
# ------------
# 64. Locating the Alternative Banks in La Crescenta-Montrose, CA
# Page: 1
# There are no more alternative banks in La Crescenta-Montrose, CA.
# ------------
# 65. Locating the Alternative Banks in Altadena, CA
# Page: 1
# There are no more alternative banks in Altadena, CA.
# ------------
# 66. Locating the Alternative Banks in Glendora, CA
# Page: 1
# There are no more alternative banks in Glendora, CA.
# ------------
# 67. Locating the Alternative Banks in Vernon, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Vernon, CA.
# ------------
# 68. Locating the Alternative Banks in View Park-Windsor Hills, CA
# Page: 1
# Page: 2
# There are no more alternative banks in View Park-Windsor Hills, CA.
# ------------
# 69. Locating the Alternative Banks in Desert View Highlands, CA
# Page: 1
# There are no more alternative banks in Desert View Highlands, CA.
# ------------
# 70. Locating the Alternative Banks in Hacienda Heights, CA
# Page: 1
# There are no more alternative banks in Hacienda Heights, CA.
# ------------
# 71. Locating the Alternative Banks in Lakewood, CA
# Page: 1
# There are no more alternative banks in Lakewood, CA.
# ------------
# 72. Locating the Alternative Banks in Green Valley, CA
# Page: 1
# There are no more alternative banks in Green Valley, CA.
# ------------
# 73. Locating the Alternative Banks in Encino, CA
# Page: 1
# There are no more alternative banks in Encino, CA.
# ------------
# 74. Locating the Alternative Banks in Quartz Hill, CA
# Page: 1
# There are no more alternative banks in Quartz Hill, CA.
# ------------
# 75. Locating the Alternative Banks in Westchester, CA
# Page: 1
# There are no more alternative banks in Westchester, CA.
# ------------
# 76. Locating the Alternative Banks in Torrance, CA
# Page: 1
# There are no more alternative banks in Torrance, CA.
# ------------
# 77. Locating the Alternative Banks in South Pasadena, CA
# Page: 1
# There are no more alternative banks in South Pasadena, CA.
# ------------
# 78. Locating the Alternative Banks in Elizabeth Lake, CA
# Page: 1
# There are no more alternative banks in Elizabeth Lake, CA.
# ------------
# 79. Locating the Alternative Banks in Arcadia, CA
# Page: 1
# There are no more alternative banks in Arcadia, CA.
# ------------
# 80. Locating the Alternative Banks in Mission Hills, CA
# Page: 1
# There are no more alternative banks in Mission Hills, CA.
# ------------
# 81. Locating the Alternative Banks in Studio City, CA
# Page: 1
# There are no more alternative banks in Studio City, CA.
# ------------
# 82. Locating the Alternative Banks in Lake Hughes, CA
# Page: 1
# There are no more alternative banks in Lake Hughes, CA.
# ------------
# 83. Locating the Alternative Banks in East Pasadena, CA
# Page: 1
# There are no more alternative banks in East Pasadena, CA.
# ------------
# 84. Locating the Alternative Banks in Tarzana, CA
# Page: 1
# There are no more alternative banks in Tarzana, CA.
# ------------
# 85. Locating the Alternative Banks in Toluca Lake, CA
# Page: 1
# There are no more alternative banks in Toluca Lake, CA.
# ------------
# 86. Locating the Alternative Banks in Angeles Crest, CA
# Page: 1
# There are no more alternative banks in Angeles Crest, CA.
# ------------
# 87. Locating the Alternative Banks in Rowland Heights, CA
# Page: 1
# There are no more alternative banks in Rowland Heights, CA.
# ------------
# 88. Locating the Alternative Banks in Rancho Dominguez, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Rancho Dominguez, CA.
# ------------
# 89. Locating the Alternative Banks in West Covina, CA
# Page: 1
# There are no more alternative banks in West Covina, CA.
# ------------
# 90. Locating the Alternative Banks in Carthay, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Carthay, CA.
# ------------
# 91. Locating the Alternative Banks in Culver City, CA
# Page: 1
# There are no more alternative banks in Culver City, CA.
# ------------
# 92. Locating the Alternative Banks in Carson, CA
# Page: 1
# There are no more alternative banks in Carson, CA.
# ------------
# 93. Locating the Alternative Banks in Southeast Antelope Valley, CA
# Page: 1
# There are no more alternative banks in Southeast Antelope Valley, CA.
# ------------
# 94. Locating the Alternative Banks in Valinda, CA
# Page: 1
# There are no more alternative banks in Valinda, CA.
# ------------
# 95. Locating the Alternative Banks in East La Mirada, CA
# Page: 1
# There are no more alternative banks in East La Mirada, CA.
# ------------
# 96. Locating the Alternative Banks in Rancho Park, CA
# Page: 1
# There are no more alternative banks in Rancho Park, CA.
# ------------
# 97. Locating the Alternative Banks in Sherman Oaks, CA
# Page: 1
# There are no more alternative banks in Sherman Oaks, CA.
# ------------
# 98. Locating the Alternative Banks in Hollywood Hills, CA
# Page: 1
# There are no more alternative banks in Hollywood Hills, CA.
# ------------
# 99. Locating the Alternative Banks in Santa Monica, CA
# Page: 1
# There are no more alternative banks in Santa Monica, CA.
# ------------
# 100. Locating the Alternative Banks in Sunland, CA
# Page: 1
# There are no more alternative banks in Sunland, CA.
# ------------
# 101. Locating the Alternative Banks in Westwood, CA
# Page: 1
# There are no more alternative banks in Westwood, CA.
# ------------
# 102. Locating the Alternative Banks in Playa Vista, CA
# Page: 1
# There are no more alternative banks in Playa Vista, CA.
# ------------
# 103. Locating the Alternative Banks in Duarte, CA
# Page: 1
# There are no more alternative banks in Duarte, CA.
# ------------
# 104. Locating the Alternative Banks in Charter Oak, CA
# Page: 1
# There are no more alternative banks in Charter Oak, CA.
# ------------
# 105. Locating the Alternative Banks in Val Verde, CA
# Page: 1
# There are no more alternative banks in Val Verde, CA.
# ------------
# 106. Locating the Alternative Banks in Lake View Terrace, CA
# Page: 1
# There are no more alternative banks in Lake View Terrace, CA.
# ------------
# 107. Locating the Alternative Banks in Northridge, CA
# Page: 1
# There are no more alternative banks in Northridge, CA.
# ------------
# 108. Locating the Alternative Banks in Venice, CA
# Page: 1
# There are no more alternative banks in Venice, CA.
# ------------
# 109. Locating the Alternative Banks in Mayflower Village, CA
# Page: 1
# There are no more alternative banks in Mayflower Village, CA.
# ------------
# 110. Locating the Alternative Banks in Eagle Rock, CA
# Page: 1
# There are no more alternative banks in Eagle Rock, CA.
# ------------
# 111. Locating the Alternative Banks in Whittier, CA
# Page: 1
# There are no more alternative banks in Whittier, CA.
# ------------
# 112. Locating the Alternative Banks in West Carson, CA
# Page: 1
# There are no more alternative banks in West Carson, CA.
# ------------
# 113. Locating the Alternative Banks in Citrus, CA
# Page: 1
# There are no more alternative banks in Citrus, CA.
# ------------
# 114. Locating the Alternative Banks in Industry, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Industry, CA.
# ------------
# 115. Locating the Alternative Banks in Del Aire, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Del Aire, CA.
# ------------
# 116. Locating the Alternative Banks in Covina, CA
# Page: 1
# There are no more alternative banks in Covina, CA.
# ------------
# 117. Locating the Alternative Banks in Signal Hill, CA
# Page: 1
# There are no more alternative banks in Signal Hill, CA.
# ------------
# 118. Locating the Alternative Banks in Vincent, CA
# Page: 1
# There are no more alternative banks in Vincent, CA.
# ------------
# 119. Locating the Alternative Banks in Temple City, CA
# Page: 1
# There are no more alternative banks in Temple City, CA.
# ------------
# 120. Locating the Alternative Banks in Fairfax, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Fairfax, CA.
# ------------
# 121. Locating the Alternative Banks in Sylmar, CA
# Page: 1
# There are no more alternative banks in Sylmar, CA.
# ------------
# 122. Locating the Alternative Banks in Arleta, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Arleta, CA.
# ------------
# 123. Locating the Alternative Banks in South San Jose Hills, CA
# Page: 1
# There are no more alternative banks in South San Jose Hills, CA.
# ------------
# 124. Locating the Alternative Banks in Lake Balboa, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Lake Balboa, CA.
# ------------
# 125. Locating the Alternative Banks in South San Gabriel, CA
# Page: 1
# There are no more alternative banks in South San Gabriel, CA.
# ------------
# 126. Locating the Alternative Banks in West Puente Valley, CA
# Page: 1
# There are no more alternative banks in West Puente Valley, CA.
# ------------
# 127. Locating the Alternative Banks in South Whittier, CA
# Page: 1
# There are no more alternative banks in South Whittier, CA.
# ------------
# 128. Locating the Alternative Banks in Avocado Heights, CA
# Page: 1
# There are no more alternative banks in Avocado Heights, CA.
# ------------
# 129. Locating the Alternative Banks in Burbank, CA
# Page: 1
# There are no more alternative banks in Burbank, CA.
# ------------
# 130. Locating the Alternative Banks in East San Gabriel, CA
# Page: 1
# There are no more alternative banks in East San Gabriel, CA.
# ------------
# 131. Locating the Alternative Banks in Pico-Robertson, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Pico-Robertson, CA.
# ------------
# 132. Locating the Alternative Banks in Palmdale, CA
# Page: 1
# There are no more alternative banks in Palmdale, CA.
# ------------
# 133. Locating the Alternative Banks in Beverly Grove, CA
# Page: 1
# There are no more alternative banks in Beverly Grove, CA.
# ------------
# 134. Locating the Alternative Banks in Pasadena, CA
# Page: 1
# There are no more alternative banks in Pasadena, CA.
# ------------
# 135. Locating the Alternative Banks in Mar Vista, CA
# Page: 1
# There are no more alternative banks in Mar Vista, CA.
# ------------
# 136. Locating the Alternative Banks in Winnetka, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Winnetka, CA.
# ------------
# 137. Locating the Alternative Banks in Norwalk, CA
# Page: 1
# There are no more alternative banks in Norwalk, CA.
# ------------
# 138. Locating the Alternative Banks in Del Rey, CA
# Page: 1
# There are no more alternative banks in Del Rey, CA.
# ------------
# 139. Locating the Alternative Banks in Downey, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Downey, CA.
# ------------
# 140. Locating the Alternative Banks in Windsor Square, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Windsor Square, CA.
# ------------
# 141. Locating the Alternative Banks in West Whittier-Los Nietos, CA
# Page: 1
# There are no more alternative banks in West Whittier-Los Nietos, CA.
# ------------
# 142. Locating the Alternative Banks in Monrovia, CA
# Page: 1
# There are no more alternative banks in Monrovia, CA.
# ------------
# 143. Locating the Alternative Banks in Lopez/Kagel Canyons, CA
# Page: 1
# There are no more alternative banks in Lopez/Kagel Canyons, CA.
# ------------
# 144. Locating the Alternative Banks in Irwindale, CA
# Page: 1
# There are no more alternative banks in Irwindale, CA.
# ------------
# 145. Locating the Alternative Banks in Littlerock, CA
# Page: 1
# There are no more alternative banks in Littlerock, CA.
# ------------
# 146. Locating the Alternative Banks in Veterans Administration, CA
# Page: 1
# There are no more alternative banks in Veterans Administration, CA.
# ------------
# 147. Locating the Alternative Banks in Artesia, CA
# Page: 1
# There are no more alternative banks in Artesia, CA.
# ------------
# 148. Locating the Alternative Banks in Santa Fe Springs, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Santa Fe Springs, CA.
# ------------
# 149. Locating the Alternative Banks in Lomita, CA
# Page: 1
# There are no more alternative banks in Lomita, CA.
# ------------
# 150. Locating the Alternative Banks in Northwest Antelope Valley, CA
# Page: 1
# There are no more alternative banks in Northwest Antelope Valley, CA.
# ------------
# 151. Locating the Alternative Banks in Mid-Wilshire, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Mid-Wilshire, CA.
# ------------
# 152. Locating the Alternative Banks in Tujunga, CA
# Page: 1
# There are no more alternative banks in Tujunga, CA.
# ------------
# 153. Locating the Alternative Banks in Gramercy Park, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Gramercy Park, CA.
# ------------
# 154. Locating the Alternative Banks in Mount Washington, CA
# Page: 1
# There are no more alternative banks in Mount Washington, CA.
# ------------
# 155. Locating the Alternative Banks in Sawtelle, CA
# Page: 1
# There are no more alternative banks in Sawtelle, CA.
# ------------
# 156. Locating the Alternative Banks in San Pedro, CA
# Page: 1
# There are no more alternative banks in San Pedro, CA.
# ------------
# 157. Locating the Alternative Banks in Alondra Park, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Alondra Park, CA.
# ------------
# 158. Locating the Alternative Banks in Glendale, CA
# Page: 1
# There are no more alternative banks in Glendale, CA.
# ------------
# 159. Locating the Alternative Banks in San Gabriel, CA
# Page: 1
# There are no more alternative banks in San Gabriel, CA.
# ------------
# 160. Locating the Alternative Banks in Pico Rivera, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Pico Rivera, CA.
# ------------
# 161. Locating the Alternative Banks in Baldwin Park, CA
# Page: 1
# There are no more alternative banks in Baldwin Park, CA.
# ------------
# 162. Locating the Alternative Banks in North El Monte, CA
# Page: 1
# There are no more alternative banks in North El Monte, CA.
# ------------
# 163. Locating the Alternative Banks in Unincorporated Catalina Island, CA
# Page: 1
# There are no more alternative banks in Unincorporated Catalina Island, CA.
# ------------
# 164. Locating the Alternative Banks in Sun Village, CA
# Page: 1
# There are no more alternative banks in Sun Village, CA.
# ------------
# 165. Locating the Alternative Banks in Lancaster, CA
# Page: 1
# There are no more alternative banks in Lancaster, CA.
# ------------
# 166. Locating the Alternative Banks in La Puente, CA
# Page: 1
# There are no more alternative banks in La Puente, CA.
# ------------
# 167. Locating the Alternative Banks in Montecito Heights, CA
# Page: 1
# There are no more alternative banks in Montecito Heights, CA.
# ------------
# 168. Locating the Alternative Banks in Valley Village, CA
# Page: 1
# There are no more alternative banks in Valley Village, CA.
# ------------
# 169. Locating the Alternative Banks in Harbor City, CA
# Page: 1
# There are no more alternative banks in Harbor City, CA.
# ------------
# 170. Locating the Alternative Banks in Monterey Park, CA
# Page: 1
# There are no more alternative banks in Monterey Park, CA.
# ------------
# 171. Locating the Alternative Banks in Reseda, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Reseda, CA.
# ------------
# 172. Locating the Alternative Banks in Silver Lake, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Silver Lake, CA.
# ------------
# 173. Locating the Alternative Banks in Pomona, CA
# Page: 1
# There are no more alternative banks in Pomona, CA.
# ------------
# 174. Locating the Alternative Banks in San Fernando, CA
# Page: 1
# There are no more alternative banks in San Fernando, CA.
# ------------
# 175. Locating the Alternative Banks in Atwater Village, CA
# Page: 1
# There are no more alternative banks in Atwater Village, CA.
# ------------
# 176. Locating the Alternative Banks in Bellflower, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Bellflower, CA.
# ------------
# 177. Locating the Alternative Banks in Azusa, CA
# Page: 1
# There are no more alternative banks in Azusa, CA.
# ------------
# 178. Locating the Alternative Banks in Alhambra, CA
# Page: 1
# There are no more alternative banks in Alhambra, CA.
# ------------
# 179. Locating the Alternative Banks in Avalon, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Avalon, CA.
# ------------
# 180. Locating the Alternative Banks in Lawndale, CA
# Page: 1
# There are no more alternative banks in Lawndale, CA.
# ------------
# 181. Locating the Alternative Banks in Gardena, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Gardena, CA.
# ------------
# 182. Locating the Alternative Banks in West Hollywood, CA
# Page: 1
# Page: 2
# There are no more alternative banks in West Hollywood, CA.
# ------------
# 183. Locating the Alternative Banks in Montebello, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Montebello, CA.
# ------------
# 184. Locating the Alternative Banks in North Hills, CA
# Page: 1
# Page: 2
# There are no more alternative banks in North Hills, CA.
# ------------
# 185. Locating the Alternative Banks in Northeast Antelope Valley, CA
# Page: 1
# There are no more alternative banks in Northeast Antelope Valley, CA.
# ------------
# 186. Locating the Alternative Banks in Lake Los Angeles, CA
# Page: 1
# There are no more alternative banks in Lake Los Angeles, CA.
# ------------
# 187. Locating the Alternative Banks in Canoga Park, CA
# Page: 1
# There are no more alternative banks in Canoga Park, CA.
# ------------
# 188. Locating the Alternative Banks in Sun Valley, CA
# Page: 1
# There are no more alternative banks in Sun Valley, CA.
# ------------
# 189. Locating the Alternative Banks in Long Beach, CA
# Page: 1
# There are no more alternative banks in Long Beach, CA.
# ------------
# 190. Locating the Alternative Banks in Los Feliz, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Los Feliz, CA.
# ------------
# 191. Locating the Alternative Banks in Palms, CA
# Page: 1
# There are no more alternative banks in Palms, CA.
# ------------
# 192. Locating the Alternative Banks in Glassell Park, CA
# Page: 1
# There are no more alternative banks in Glassell Park, CA.
# ------------
# 193. Locating the Alternative Banks in Paramount, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Paramount, CA.
# ------------
# 194. Locating the Alternative Banks in Rosemead, CA
# Page: 1
# There are no more alternative banks in Rosemead, CA.
# ------------
# 195. Locating the Alternative Banks in Pacoima, CA
# Page: 1
# There are no more alternative banks in Pacoima, CA.
# ------------
# 196. Locating the Alternative Banks in Elysian Valley, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Elysian Valley, CA.
# ------------
# 197. Locating the Alternative Banks in Athens, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Athens, CA.
# ------------
# 198. Locating the Alternative Banks in Walnut Park, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Walnut Park, CA.
# ------------
# 199. Locating the Alternative Banks in Lynwood, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Lynwood, CA.
# ------------
# 200. Locating the Alternative Banks in South Gate, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in South Gate, CA.
# ------------
# 201. Locating the Alternative Banks in West Compton, CA
# Page: 1
# Page: 2
# There are no more alternative banks in West Compton, CA.
# ------------
# 202. Locating the Alternative Banks in Harbor Gateway, CA
# Page: 1
# There are no more alternative banks in Harbor Gateway, CA.
# ------------
# 203. Locating the Alternative Banks in Larchmont, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Larchmont, CA.
# ------------
# 204. Locating the Alternative Banks in South El Monte, CA
# Page: 1
# There are no more alternative banks in South El Monte, CA.
# ------------
# 205. Locating the Alternative Banks in Hawaiian Gardens, CA
# Page: 1
# There are no more alternative banks in Hawaiian Gardens, CA.
# ------------
# 206. Locating the Alternative Banks in Inglewood, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Inglewood, CA.
# ------------
# 207. Locating the Alternative Banks in Commerce, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Commerce, CA.
# ------------
# 208. Locating the Alternative Banks in Valley Glen, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Valley Glen, CA.
# ------------
# 209. Locating the Alternative Banks in Manchester Square, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Manchester Square, CA.
# ------------
# 210. Locating the Alternative Banks in El Sereno, CA
# Page: 1
# There are no more alternative banks in El Sereno, CA.
# ------------
# 211. Locating the Alternative Banks in Leimert Park, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Leimert Park, CA.
# ------------
# 212. Locating the Alternative Banks in Highland Park, CA
# Page: 1
# There are no more alternative banks in Highland Park, CA.
# ------------
# 213. Locating the Alternative Banks in Panorama City, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Panorama City, CA.
# ------------
# 214. Locating the Alternative Banks in East Compton, CA
# Page: 1
# Page: 2
# There are no more alternative banks in East Compton, CA.
# ------------
# 215. Locating the Alternative Banks in El Monte, CA
# Page: 1
# There are no more alternative banks in El Monte, CA.
# ------------
# 216. Locating the Alternative Banks in Mid-City, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Mid-City, CA.
# ------------
# 217. Locating the Alternative Banks in Hawthorne, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Hawthorne, CA.
# ------------
# 218. Locating the Alternative Banks in Compton, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Compton, CA.
# ------------
# 219. Locating the Alternative Banks in North Hollywood, CA
# Page: 1
# There are no more alternative banks in North Hollywood, CA.
# ------------
# 220. Locating the Alternative Banks in Cypress Park, CA
# Page: 1
# There are no more alternative banks in Cypress Park, CA.
# ------------
# 221. Locating the Alternative Banks in Bell Gardens, CA
# Page: 1
# There are no more alternative banks in Bell Gardens, CA.
# ------------
# 222. Locating the Alternative Banks in Maywood, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Maywood, CA.
# ------------
# 223. Locating the Alternative Banks in Van Nuys, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Van Nuys, CA.
# ------------
# 224. Locating the Alternative Banks in Wilmington, CA
# Page: 1
# There are no more alternative banks in Wilmington, CA.
# ------------
# 225. Locating the Alternative Banks in Bell, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Bell, CA.
# ------------
# 226. Locating the Alternative Banks in Hyde Park, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Hyde Park, CA.
# ------------
# 227. Locating the Alternative Banks in Huntington Park, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Huntington Park, CA.
# ------------
# 228. Locating the Alternative Banks in Cudahy, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Cudahy, CA.
# ------------
# 229. Locating the Alternative Banks in East Los Angeles, CA
# Page: 1
# Page: 2
# There are no more alternative banks in East Los Angeles, CA.
# ------------
# 230. Locating the Alternative Banks in Willowbrook, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Willowbrook, CA.
# ------------
# 231. Locating the Alternative Banks in West Adams, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in West Adams, CA.
# ------------
# 232. Locating the Alternative Banks in Baldwin Hills/Crenshaw, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Baldwin Hills/Crenshaw, CA.
# ------------
# 233. Locating the Alternative Banks in Lennox, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Lennox, CA.
# ------------
# 234. Locating the Alternative Banks in Chesterfield Square, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Chesterfield Square, CA.
# ------------
# 235. Locating the Alternative Banks in Echo Park, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Echo Park, CA.
# ------------
# 236. Locating the Alternative Banks in Harvard Park, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Harvard Park, CA.
# ------------
# 237. Locating the Alternative Banks in Florence-Firestone, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Florence-Firestone, CA.
# ------------
# 238. Locating the Alternative Banks in Exposition Park, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Exposition Park, CA.
# ------------
# 239. Locating the Alternative Banks in Hollywood, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Hollywood, CA.
# ------------
# 240. Locating the Alternative Banks in Boyle Heights, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Boyle Heights, CA.
# ------------
# 241. Locating the Alternative Banks in Jefferson Park, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Jefferson Park, CA.
# ------------
# 242. Locating the Alternative Banks in Westmont, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Westmont, CA.
# ------------
# 243. Locating the Alternative Banks in Central-Alameda, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Central-Alameda, CA.
# ------------
# 244. Locating the Alternative Banks in Arlington Heights, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Arlington Heights, CA.
# ------------
# 245. Locating the Alternative Banks in Green Meadows, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Green Meadows, CA.
# ------------
# 246. Locating the Alternative Banks in Vermont Vista, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Vermont Vista, CA.
# ------------
# 247. Locating the Alternative Banks in Vermont-Slauson, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Vermont-Slauson, CA.
# ------------
# 248. Locating the Alternative Banks in Harvard Heights, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Harvard Heights, CA.
# ------------
# 249. Locating the Alternative Banks in Historic South-Central, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Historic South-Central, CA.
# ------------
# 250. Locating the Alternative Banks in Lincoln Heights, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Lincoln Heights, CA.
# ------------
# 251. Locating the Alternative Banks in Koreatown, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Koreatown, CA.
# ------------
# 252. Locating the Alternative Banks in East Hollywood, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in East Hollywood, CA.
# ------------
# 253. Locating the Alternative Banks in Vermont Square, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Vermont Square, CA.
# ------------
# 254. Locating the Alternative Banks in Broadway-Manchester, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Broadway-Manchester, CA.
# ------------
# 255. Locating the Alternative Banks in Adams-Normandie, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Adams-Normandie, CA.
# ------------
# 256. Locating the Alternative Banks in South Park, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in South Park, CA.
# ------------
# 257. Locating the Alternative Banks in Florence, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Florence, CA.
# ------------
# 258. Locating the Alternative Banks in Elysian Park, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Elysian Park, CA.
# ------------
# 259. Locating the Alternative Banks in Vermont Knolls, CA
# Page: 1
# Page: 2
# There are no more alternative banks in Vermont Knolls, CA.
# ------------
# 260. Locating the Alternative Banks in Westlake, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Westlake, CA.
# ------------
# 261. Locating the Alternative Banks in Pico-Union, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Pico-Union, CA.
# ------------
# 262. Locating the Alternative Banks in Watts, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Watts, CA.
# ------------
# 263. Locating the Alternative Banks in Chinatown, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Chinatown, CA.
# ------------
# 264. Locating the Alternative Banks in University Park, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in University Park, CA.
# ------------
# 265. Locating the Alternative Banks in Downtown, CA
# Page: 1
# Page: 2
# Page: 3
# There are no more alternative banks in Downtown, CA.
# ------------

# %%
altbank_df=pd.DataFrame.from_dict(altbank_data, orient='index')
altbank_df = altbank_df.transpose()

# %%
cols = ['Alt Bank Name', 'Alt Bank Lat', 'Alt Bank Long']
altbank_df=altbank_df.dropna()
altbank_df['combined'] = altbank_df[cols].apply(lambda row: '_'.join(row.values.astype(str)), axis=1)
altbank_df.head()
# Out:
#        Neighborhood                 Alt Bank Name Alt Bank Lat Alt Bank Long  \
# 0  La Habra Heights                Cashback Loans      33.9253      -117.896
# 1  La Habra Heights                   Check `n Go      33.9314      -117.968
# 2  Westlake Village                    Union Bank       34.163      -118.826
# 3  Westlake Village  Kinecta Federal Credit Union      34.1529       -118.83
# 4    Ladera Heights                    Union Bank      34.1546      -118.758
#
#                                             combined
# 0             Cashback Loans_33.9253098_-117.8961903
# 1                Check `n Go_33.9314409_-117.9684327
# 2                  Union Bank_34.1629999_-118.825759
# 3  Kinecta Federal Credit Union_34.152877_-118.82...
# 4                 Union Bank_34.1546014_-118.7578941

# %%
altbank_df=altbank_df.drop_duplicates(['combined'], keep='last')
altbank_df = altbank_df.reset_index(drop=True)
altbank_df.head()
# Out:
#        Neighborhood                 Alt Bank Name Alt Bank Lat Alt Bank Long  \
# 0  La Habra Heights                Cashback Loans      33.9253      -117.896
# 1  La Habra Heights                   Check `n Go      33.9314      -117.968
# 2  Westlake Village                    Union Bank       34.163      -118.826
# 3  Westlake Village  Kinecta Federal Credit Union      34.1529       -118.83
# 4    Ladera Heights                    Union Bank      34.1546      -118.758
#
#                                             combined
# 0             Cashback Loans_33.9253098_-117.8961903
# 1                Check `n Go_33.9314409_-117.9684327
# 2                  Union Bank_34.1629999_-118.825759
# 3  Kinecta Federal Credit Union_34.152877_-118.82...
# 4                 Union Bank_34.1546014_-118.7578941

# %%
altbank_df=altbank_df.drop(['combined'], axis=1)
altbank_df.head()
# Out:
#        Neighborhood                 Alt Bank Name Alt Bank Lat Alt Bank Long
# 0  La Habra Heights                Cashback Loans      33.9253      -117.896
# 1  La Habra Heights                   Check `n Go      33.9314      -117.968
# 2  Westlake Village                    Union Bank       34.163      -118.826
# 3  Westlake Village  Kinecta Federal Credit Union      34.1529       -118.83
# 4    Ladera Heights                    Union Bank      34.1546      -118.758

# %%
altbank_df.to_csv(path_or_buf="LA_Alt_Banks.csv", sep=',')
