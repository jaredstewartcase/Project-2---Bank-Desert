# %%
# Dependencies
import os
from bs4 import BeautifulSoup as bs
import requests
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
import pandas as pd
import csv
import json
import sys, getopt, pprint
from pymongo import MongoClient

# %%
# URL of page to be scraped
url = 'http://maps.latimes.com/neighborhoods/income/median/neighborhood/list/'
 # https://splinter.readthedocs.io/en/latest/drivers/chrome.html
get_ipython().system('which chromedriver')
executable_path = {'executable_path': 'chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# which: no chromedriver in (/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/envs/PythonData:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/envs/PythonData/Library/mingw-w64/bin:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/envs/PythonData/Library/usr/bin:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/envs/PythonData/Library/bin:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/envs/PythonData/Scripts:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/envs/PythonData/bin:/c/Users/Tom.LAPTOP-UESBC4IO/bin:/mingw64/bin:/usr/local/bin:/usr/bin:/usr/bin:/mingw64/bin:/usr/bin:/c/Users/Tom.LAPTOP-UESBC4IO/bin:/c/Windows/system32:/c/Windows:/c/Windows/System32/Wbem:/c/Windows/System32/WindowsPowerShell/v1.0:/c/Windows/System32/OpenSSH:/c/Program Files/Intel/WiFi/bin:/c/Program Files/Common Files/Intel/WirelessCommon:/cmd:/c/Program Files/MySQL/MySQL Utilities 1.6:/c/Program Files (x86)/Intel/Intel(R) Management Engine Components/DAL:/c/Program Files/Intel/Intel(R) Management Engine Components/DAL:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/Library/mingw-w64/bin:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/Library/usr/bin:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/Library/bin:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/Scripts:/c/Users/Tom.LAPTOP-UESBC4IO/AppData/Local/Microsoft/WindowsApps:/c/Program Files/heroku/bin:/c/Program Files/MongoDB/Server/4.0/bin:/c/Users/Tom.LAPTOP-UESBC4IO/AppData/Local/Programs/Microsoft VS Code/bin:/usr/bin/vendor_perl:/usr/bin/core_perl)

# %%
# Retrieve page with the requests module
browser.visit(url)  
html = browser.html

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soup = bs(html, 'html.parser')

# %%
# Print all ten headlines
tds = soup.find_all('td')
# A blank list to hold the headlines
headlines = []
# Loop over td elements
for td in tds:
   # If td element has an anchor...
   if (td.a):
#        print(td.a)
       # And the anchor has non-blank text...
       if (td.a.text):
           # Append the td to the list
           headlines.append(td)
# Out:
# <a href="/neighborhoods/neighborhood/bel-air/" name="bel-air">Bel-Air</a>
# <a href="/neighborhoods/neighborhood/hidden-hills/" name="hidden-hills">Hidden Hills</a>
# <a href="/neighborhoods/neighborhood/rolling-hills/" name="rolling-hills">Rolling Hills</a>
# <a href="/neighborhoods/neighborhood/beverly-crest/" name="beverly-crest">Beverly Crest</a>
# <a href="/neighborhoods/neighborhood/pacific-palisades/" name="pacific-palisades">Pacific Palisades</a>
# <a href="/neighborhoods/neighborhood/palos-verdes-estates/" name="palos-verdes-estates">Palos Verdes Estates</a>
# <a href="/neighborhoods/neighborhood/san-marino/" name="san-marino">San Marino</a>
# <a href="/neighborhoods/neighborhood/la-canada-flintridge/" name="la-canada-flintridge">La Cañada Flintridge</a>
# <a href="/neighborhoods/neighborhood/rolling-hills-estates/" name="rolling-hills-estates">Rolling Hills Estates</a>
# <a href="/neighborhoods/neighborhood/malibu/" name="malibu">Malibu</a>
# <a href="/neighborhoods/neighborhood/la-habra-heights/" name="la-habra-heights">La Habra Heights</a>
# <a href="/neighborhoods/neighborhood/harvard-heights/" name="harvard-heights">Harvard Heights</a>
# <a href="/neighborhoods/neighborhood/historic-south-central/" name="historic-south-central">Historic South-Central</a>
# <a href="/neighborhoods/neighborhood/lincoln-heights/" name="lincoln-heights">Lincoln Heights</a>
# <a href="/neighborhoods/neighborhood/koreatown/" name="koreatown">Koreatown</a>
# <a href="/neighborhoods/neighborhood/east-hollywood/" name="east-hollywood">East Hollywood</a>
# <a href="/neighborhoods/neighborhood/vermont-square/" name="vermont-square">Vermont Square</a>
# <a href="/neighborhoods/neighborhood/broadway-manchester/" name="broadway-manchester">Broadway-Manchester</a>
# <a href="/neighborhoods/neighborhood/adams-normandie/" name="adams-normandie">Adams-Normandie</a>
# <a href="/neighborhoods/neighborhood/south-park/" name="south-park">South Park</a>
# <a href="/neighborhoods/neighborhood/florence/" name="florence">Florence</a>
# <a href="/neighborhoods/neighborhood/elysian-park/" name="elysian-park">Elysian Park</a>
# <a href="/neighborhoods/neighborhood/vermont-knolls/" name="vermont-knolls">Vermont Knolls</a>
# <a href="/neighborhoods/neighborhood/westlake/" name="westlake">Westlake</a>
# <a href="/neighborhoods/neighborhood/pico-union/" name="pico-union">Pico-Union</a>
# <a href="/neighborhoods/neighborhood/watts/" name="watts">Watts</a>
# <a href="/neighborhoods/neighborhood/chinatown/" name="chinatown">Chinatown</a>
# <a href="/neighborhoods/neighborhood/university-park/" name="university-park">University Park</a>
# <a href="/neighborhoods/neighborhood/downtown/" name="downtown">Downtown</a>

# %%
# Print only the headlines
neighborhoods = []
for x in range(len(headlines)):
#    print(headlines[x].text)
   neighborhoods.append(headlines[x].text)

# %%
neighborhoods
names = []
for neighbor in neighborhoods:
    name =neighbor.replace("\n", "")
    names.append(name)
# Out:
# Bel-Air
# Hidden Hills
# Rolling Hills
# Beverly Crest
# Pacific Palisades
# Palos Verdes Estates
# San Marino
# La Cañada Flintridge
# Rolling Hills Estates
# Malibu
# La Habra Heights
# Manhattan Beach
# Unincorporated Santa Monica Mountains
# Rancho Palos Verdes
# Westlake Village
# Calabasas
# West San Dimas
# Bradbury
# Stevenson Ranch
# Porter Ranch
# Topanga
# Ladera Heights
# Agoura Hills
# Leona Valley
# Brentwood
# Cheviot Hills
# Hermosa Beach
# Castaic
# Hollywood Hills West
# Walnut
# Hasley Canyon
# Agua Dulce
# Beverlywood
# Northwest Palmdale
# West Hills
# Cerritos
# Beverly Hills
# Century City
# North Whittier
# Unincorporated Santa Susana Mountains
# Castaic Canyons
# San Pasqual
# Ridge Route
# Marina del Rey
# Diamond Bar
# Redondo Beach
# Playa del Rey
# Woodland Hills
# Claremont
# Santa Clarita
# Sierra Madre
# West Los Angeles
# Ramona
# Tujunga Canyons
# Hancock Park
# San Dimas
# Chatsworth
# Acton
# El Segundo
# Granada Hills
# La Mirada
# La Verne
# Shadow Hills
# La Crescenta-Montrose
# Altadena
# Glendora
# $51,601
# $51,290
# $50,985
# $50,793
# $50,684
# $50,098
# $49,815
# $49,387
# $49,066
# $49,013
# $48,824
# $48,750
# $48,518
# $48,312
# $48,093
# $47,849
# $47,780
# $46,912
# $46,853
# $46,574
# $46,245
# $46,175
# $46,093
# $45,866
# $45,865
# $45,478
# $44,468
# $44,439
# $44,415
# $43,711
# $43,602
# $43,157
# $42,791
# $42,615
# $41,532
# $41,203
# $41,134
# $40,627
# $40,556
# $39,460
# $39,185
# $39,048
# $38,621
# $38,224
# $38,209
# $37,948
# $37,937
# $37,737
# $37,708
# $37,013
# $34,408
# $33,999
# $33,694
# $33,235
# $32,654
# $31,572
# $31,559
# $31,421
# $31,347
# $31,272
# $31,236
# $31,173
# $30,882
# $30,579
# $30,558
# $29,927
# $29,904
# $29,897
# $29,606
# $29,518
# $29,447
# $28,263
# $27,730
# $26,757
# $26,424
# $25,161
# $22,754
# $18,533
# $15,003

# %%
# make the dictionary containing the titles and the image url
La_times = [
    {"Median Rank":rank},
    {"Neighborhood":names},
    {"Median Income":median_income}]

# %%
rank_df = pd.DataFrame(rank)    
rank_df.head()
median_income_df = pd.DataFrame(median_income)
median_income_df.head()
name_df = pd.DataFrame(names)

# %%
#combine data frames to get data all in one place
LA_Times = pd.DataFrame({'Median Rank' : rank,
 'LA Neighborhood' : names,
 'Median Income':median_income
  }, columns=['Median Rank','LA Neighborhood', 'Median Income'])

# %%
#scrape diversity index stats 

url = 'http://maps.latimes.com/neighborhoods/diversity/neighborhood/list/'
 # https://splinter.readthedocs.io/en/latest/drivers/chrome.html
get_ipython().system('which chromedriver')
executable_path = {'executable_path': 'chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# which: no chromedriver in (/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/envs/PythonData:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/envs/PythonData/Library/mingw-w64/bin:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/envs/PythonData/Library/usr/bin:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/envs/PythonData/Library/bin:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/envs/PythonData/Scripts:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/envs/PythonData/bin:/c/Users/Tom.LAPTOP-UESBC4IO/bin:/mingw64/bin:/usr/local/bin:/usr/bin:/usr/bin:/mingw64/bin:/usr/bin:/c/Users/Tom.LAPTOP-UESBC4IO/bin:/c/Windows/system32:/c/Windows:/c/Windows/System32/Wbem:/c/Windows/System32/WindowsPowerShell/v1.0:/c/Windows/System32/OpenSSH:/c/Program Files/Intel/WiFi/bin:/c/Program Files/Common Files/Intel/WirelessCommon:/cmd:/c/Program Files/MySQL/MySQL Utilities 1.6:/c/Program Files (x86)/Intel/Intel(R) Management Engine Components/DAL:/c/Program Files/Intel/Intel(R) Management Engine Components/DAL:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/Library/mingw-w64/bin:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/Library/usr/bin:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/Library/bin:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/Scripts:/c/Users/Tom.LAPTOP-UESBC4IO/AppData/Local/Microsoft/WindowsApps:/c/Program Files/heroku/bin:/c/Program Files/MongoDB/Server/4.0/bin:/c/Users/Tom.LAPTOP-UESBC4IO/AppData/Local/Programs/Microsoft VS Code/bin:/usr/bin/vendor_perl:/usr/bin/core_perl)

# %%
# Retrieve page with the requests module
browser.visit(url)  
html = browser.html

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soup = bs(html, 'html.parser')

# %%
# Print all ten headlines
tds1 = soup.find_all('td')
# A blank list to hold the headlines
headlines1 = []
# Loop over td elements
for td in tds1:
   # If td element has an anchor...
   if (td.a):
#       print(td.a)
       # And the anchor has non-blank text...
       if (td.a.text):
           # Append the td to the list
           headlines1.append(td)

# %%
# Print only the headlines
neighborhoods1 = []
for x in range(len(headlines1)):
#   print(headlines1[x].text)
   neighborhoods1.append(headlines1[x].text)

# %%
neighborhoods1
names1 = []
for neighbor in neighborhoods1:
    name =neighbor.replace("\n", "")
    
    names1.append(name)

# %%
# Print all ten headlines
trs1 = soup.find_all('tr')
# A blank list to hold the headlines
headlines1 = []
# Loop over td elements
for tr in trs1:
   # If td element has an anchor...
   if (tr.td):
#       print(tr.td)
    # And the anchor has non-blank text...
       if (tr.td.text):
           # Append the td to the list
           headlines1.append(tr.td.text)

# %%
# Print only the headlines
neighborhoods2 = []
for x in range(len(headlines2)):
#   print(headlines1[x].text)
   neighborhoods2.append(headlines2[x].text)

# %%
rows1 = soup.find(class_="datagrid").find("tbody").find_all("tr")
c = 0
d = 1
diversity_index = []
rank1 = []
for row in rows:
    diversity_div = rows1[c].find_all("td")[2].get_text()
    diversity_index.append(diversity_div)
    rank1.append(d)
    c += 1
    d += 1

# %%
LA_Times_diversity = pd.DataFrame({'Diversity Rank' : rank1,
 'LA Neighborhood' : names1,
 'Diversity Index':diversity_index
  }, columns=['Diversity Rank','LA Neighborhood', 'Diversity Index'])
LA_Times_diversity.head()
# Out:
#    Diversity Rank LA Neighborhood Diversity Index
# 0               1    Mid-Wilshire           0.755
# 1               2    Alondra Park           0.748
# 2               3     West Carson           0.748
# 3               4         Gardena           0.748
# 4               5        Downtown           0.743

# %%
#scrape population density stats 

url = 'http://maps.latimes.com/neighborhoods/population/density/neighborhood/list/'
 # https://splinter.readthedocs.io/en/latest/drivers/chrome.html
get_ipython().system('which chromedriver')
executable_path = {'executable_path': 'chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# which: no chromedriver in (/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/envs/PythonData:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/envs/PythonData/Library/mingw-w64/bin:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/envs/PythonData/Library/usr/bin:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/envs/PythonData/Library/bin:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/envs/PythonData/Scripts:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/envs/PythonData/bin:/c/Users/Tom.LAPTOP-UESBC4IO/bin:/mingw64/bin:/usr/local/bin:/usr/bin:/usr/bin:/mingw64/bin:/usr/bin:/c/Users/Tom.LAPTOP-UESBC4IO/bin:/c/Windows/system32:/c/Windows:/c/Windows/System32/Wbem:/c/Windows/System32/WindowsPowerShell/v1.0:/c/Windows/System32/OpenSSH:/c/Program Files/Intel/WiFi/bin:/c/Program Files/Common Files/Intel/WirelessCommon:/cmd:/c/Program Files/MySQL/MySQL Utilities 1.6:/c/Program Files (x86)/Intel/Intel(R) Management Engine Components/DAL:/c/Program Files/Intel/Intel(R) Management Engine Components/DAL:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/Library/mingw-w64/bin:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/Library/usr/bin:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/Library/bin:/c/Users/Tom.LAPTOP-UESBC4IO/Anaconda3/Scripts:/c/Users/Tom.LAPTOP-UESBC4IO/AppData/Local/Microsoft/WindowsApps:/c/Program Files/heroku/bin:/c/Program Files/MongoDB/Server/4.0/bin:/c/Users/Tom.LAPTOP-UESBC4IO/AppData/Local/Programs/Microsoft VS Code/bin:/usr/bin/vendor_perl:/usr/bin/core_perl)

# %%
# Retrieve page with the requests module
browser.visit(url)  
html = browser.html

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soup = bs(html, 'html.parser')

# %%
# Print all ten headlines
tds2 = soup.find_all('td')
# A blank list to hold the headlines
headlines2 = []
# Loop over td elements
for td in tds2:
   # If td element has an anchor...
   if (td.a):
#         print(td.a)
       # And the anchor has non-blank text...
        if (td.a.text):
           # Append the td to the list
           headlines2.append(td)

# %%
# Print only the headlines
neighborhoods2 = []
for x in range(len(headlines2)):
#   print(headlines2[x].text)
   neighborhoods2.append(headlines2[x].text)

# %%
neighborhoods2
names2 = []
for neighbor in neighborhoods2:
    name =neighbor.replace("\n", "")
    
    names2.append(name)

# %%
# Print all ten headlines
tds2 = soup.find_all('td')
# A blank list to hold the headlines
headlines2 = []
# Loop over td elements
for td in tds2:
   # If td element has an anchor...
   if (td.a):
#         print(td.a)
       # And the anchor has non-blank text...
        if (td.a.text):
           # Append the td to the list
           headlines2.append(td)

# %%
rows2 = soup.find(class_="datagrid").find("tbody").find_all("tr")
c = 0
d = 1
population_density = []
rank2 = []
for row in rows:
    popdensity_div = rows2[c].find_all("td")[2].get_text()
    population_density.append(popdensity_div)
    rank2.append(d)
    c += 1
    d += 1

# %%
LA_Times_popdensity = pd.DataFrame({'Population Density Rank' : rank2,
 'LA Neighborhood' : names2,
 'Population Per Sq Mile':population_density
  }, columns=['Population Density Rank','LA Neighborhood', 'Population Per Sq Mile'])
LA_Times_popdensity
# Out:
#      Population Density Rank                        LA Neighborhood  \
# 0                          1                              Koreatown
# 1                          2                               Westlake
# 2                          3                         East Hollywood
# 3                          4                             Pico-Union
# 4                          5                                Maywood
# 5                          6                        Harvard Heights
# 6                          7                              Hollywood
# 7                          8                            Walnut Park
# 8                          9                                  Palms
# 9                         10                        Adams-Normandie
# 10                        11                             South Park
# 11                        12                                 Lennox
# 12                        13                      Arlington Heights
# 13                        14                        Huntington Park
# 14                        15                        University Park
# 15                        16                                 Cudahy
# 16                        17                 Historic South-Central
# 17                        18                         West Hollywood
# 18                        19                        Central-Alameda
# 19                        20                        Vermont-Slauson
# 20                        21                         Vermont Knolls
# 21                        22                          Panorama City
# 22                        23                         Vermont Square
# 23                        24                           Bell Gardens
# 24                        25                              Larchmont
# 25                        26                         Pico-Robertson
# 26                        27                                  Watts
# 27                        28                               Westmont
# 28                        29                              Echo Park
# 29                        30                       East Los Angeles
# ..                       ...                                    ...
# 235                      236                          Rolling Hills
# 236                      237                               Palmdale
# 237                      238                         North Whittier
# 238                      239                             Littlerock
# 239                      240                Veterans Administration
# 240                      241                               Bradbury
# 241                      242                                 Malibu
# 242                      243                     Northwest Palmdale
# 243                      244                                Topanga
# 244                      245                           Green Valley
# 245                      246                         Elizabeth Lake
# 246                      247                    Lopez/Kagel Canyons
# 247                      248                                  Acton
# 248                      249                              Irwindale
# 249                      250                          Hasley Canyon
# 250                      251  Unincorporated Santa Monica Mountains
# 251                      252                             Agua Dulce
# 252                      253                           Leona Valley
# 253                      254                               Industry
# 254                      255                            Lake Hughes
# 255                      256  Unincorporated Santa Susana Mountains
# 256                      257                        Castaic Canyons
# 257                      258              Southeast Antelope Valley
# 258                      259                                 Vernon
# 259                      260              Northwest Antelope Valley
# 260                      261                        Tujunga Canyons
# 261                      262              Northeast Antelope Valley
# 262                      263                            Ridge Route
# 263                      264                          Angeles Crest
# 264                      265         Unincorporated Catalina Island
#
#     Population Per Sq Mile
# 0                   42,611
# 1                   38,214
# 2                   31,095
# 3                   25,352
# 4                   23,638
# 5                   23,473
# 6                   22,193
# 7                   22,028
# 8                   21,870
# 9                   21,848
# 10                  21,638
# 11                  21,557
# 12                  21,423
# 13                  20,223
# 14                  20,217
# 15                  19,697
# 16                  19,474
# 17                  18,924
# 18                  18,760
# 19                  18,577
# 20                  18,057
# 21                  18,028
# 22                  17,798
# 23                  17,762
# 24                  17,747
# 25                  17,468
# 26                  17,346
# 27                  17,066
# 28                  16,868
# 29                  16,863
# ..                     ...
# 235                    893
# 236                    874
# 237                    797
# 238                    766
# 239                    683
# 240                    658
# 241                    629
# 242                    540
# 243                    386
# 244                    290
# 245                    219
# 246                    195
# 247                    166
# 248                    154
# 249                    136
# 250                    100
# 251                     99
# 252                     90
# 253                     82
# 254                     61
# 255                     58
# 256                     40
# 257                     27
# 258                     18
# 259                     16
# 260                     11
# 261                     10
# 262                      7
# 263                      3
# 264                      2
#
# [265 rows x 3 columns]

# %%
final_location_table1 = pd.merge(LA_Times, LA_Times_diversity, on="LA Neighborhood", how="left")

# %%
final_location_table = pd.merge(final_location_table1, LA_Times_popdensity, on="LA Neighborhood", how="left")

# %%
final_location_table = final_location_table.set_index("LA Neighborhood")
final_location_table.head()
# Out:
#                    Median Rank Median Income  Diversity Rank Diversity Index  \
# LA Neighborhood
# Bel-Air                      1      $207,938             228           0.301
# Hidden Hills                 2      $203,199             251           0.207
# Rolling Hills                3      $184,777             193           0.396
# Beverly Crest                4      $169,282             245           0.230
# Pacific Palisades            5      $168,008             250           0.210
#
#                    Population Density Rank Population Per Sq Mile
# LA Neighborhood
# Bel-Air                                225                  1,207
# Hidden Hills                           229                  1,100
# Rolling Hills                          236                    893
# Beverly Crest                          223                  1,318
# Pacific Palisades                      230                  1,048

# %%
final_location_table.to_csv(path_or_buf="LA_Locations.csv", sep=',')

# %%
#CSV to JSON Conversion
csvfile = open('LA_Locations.csv', 'r')
reader = csv.DictReader( csvfile )
mongo_client=MongoClient() 
db=mongo_client.BankData
db.neighborhoodData.drop()
header= [ "LA Neighborhood", "Median Rank", "Median Income", "Diversity Rank", "Diversity Index"]

for each in reader:
    row={}
    for field in header:
        row[field]=each[field]

    db.neighborhoodData.insert(row)
# Out:
# C:\Users\Tom.LAPTOP-UESBC4IO\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
